#   8.43457023e+00 4.45812783e+00 9.07080365e+00 5.30681883e+00
#   1.86346203e+00 5.69543726e+00 7.30440402e-01]
#  [4.57161466e+00 2.18618416e+00 7.69913188e+00 1.54330254e+02
#   3.90833740e+00 6.77670866e+00 2.97439889e+00 4.71966612e+00
#   3.24174919e+00 4.32426811e+00 6.13148246e-01]
#  [1.96353175e+00 2.32691033e+00 9.60183114e+00 3.39609871e+00
#   3.87219047e+02 5.65720133e+00 2.78983040e+00 6.29494733e+00
#   9.85874196e+00 6.37091746e+00 5.47628568e+00]
#  [8.54959526e+00 4.09387599e-01 5.63253428e+00 8.82397808e+00
#   5.82133819e+00 3.90573337e+02 4.72892139e+00 4.89641154e+00
#   3.38815690e+00 3.82783438e+00 7.53906401e+00]
#  [7.69850281e+00 8.40441174e+00 9.71762736e+00 8.34906790e-01
#   6.69981352e+00 4.44473571e+00 4.04822337e+02 3.71683617e+00
#   8.82586433e+00 7.26306675e+00 1.71533766e-01]
#  [7.15002359e+00 7.43596770e+00 7.01829850e+00 3.79228642e-01
#   6.97958368e+00 5.23787683e+00 7.56600338e+00 2.43958974e+02
#   6.05353168e+00 2.04401510e+00 5.32803840e+00]
#  [9.40366473e+00 2.48105306e+00 6.68027130e+00 6.56935016e+00
#   8.39985076e+00 9.09406323e-01 5.03128193e+00 7.65177493e+00
#   3.29050386e+02 3.40444082e+00 7.13903742e+00]
#  [5.34895714e+00 7.24189967e+00 2.02858567e+00 9.06272219e+00
#   4.05488942e-01 8.10807876e+00 8.62805517e+00 9.05539026e+00
#   9.72763556e+00 1.06621258e+02 9.46096132e+00]]

# %%
def seidel(A, B, eps = 10 **(-16)):
    x = np.zeros(n)  # zero vector
    converge = False
    while not converge:
        x_new = np.copy(x)
        for i in range(n):
            s1 = sum(A[i][j] * x_new[j] for j in range(i))
            s2 = sum(A[i][j] * x[j] for j in range(i + 1, n))
            x_new[i] = (B[i] - s1 - s2) / A[i][i]

        #converge = np.sqrt(sum((x_new[i] - x[i]) ** 2 for i in range(n))) <= eps
        converge = np.linalg.norm(x_new[i] - x[i])  <= eps
        x = x_new
    return x

# %%
def condition(A):  
    return np.linalg.norm(A, np.inf) * np.linalg.norm(np.linalg.inv(A), np.inf)

# %%
def error(xi):
  #return np.sqrt(np.sum(np.power(abs(x_real-xi), 2)))
  return np.linalg.norm(x_real-xi)

def delta(xi):
  return np.linalg.norm(np.dot(A, xi) - B.T)

# %%
x_real = solve(A, B).reshape(1,n)
print('Истинное решение:  \n', x_real, '\n')

x_gauss_seidel = seidel(A, B)
print('Полученное решение методом Гаусса-Зейделя: \n', x_gauss_seidel,'\n Ошибка: ', error(x_gauss_seidel), '\n Невязка:', delta(x_gauss_seidel),'\n')
print('\n Число обусловленности:', condition(A))
# Out:
# Истинное решение:
#  [[-0.00041923 -0.00613131 -0.0004245  -0.00035766  0.01171849  0.01792664
#   -0.00195905  0.02018623  0.02010835  0.08441195]]
#
# Полученное решение методом Гаусса-Зейделя:
#  [-0.00041923 -0.00613131 -0.0004245  -0.00035766  0.01171849  0.01792664
#  -0.00195905  0.02018623  0.02010835  0.08441195]
#  Ошибка:  7.138475120425931e-17
#  Невязка: 9.09180472805593e-15
#
#
#  Число обусловленности: 7.62239689333787
